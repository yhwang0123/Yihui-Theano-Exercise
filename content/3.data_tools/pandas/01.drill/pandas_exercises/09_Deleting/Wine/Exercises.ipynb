# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
wine = pd.read_csv(url)
wine.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine = wine.drop(wine.columns[[0,3,6,8,11,12,13]], axis = 1)
wine.head()
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  5.64
# 0  13.20  1.78  11.2  100  2.76  1.28  4.38
# 1  13.16  2.36  18.6  101  3.24  2.81  5.68
# 2  14.37  1.95  16.8  113  3.49  2.18  7.80
# 3  13.24  2.59  21.0  118  2.69  1.82  4.32
# 4  14.20  1.76  15.2  112  3.39  1.97  6.75

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.columns = ['alcohol', 'malic_acid', 'alcalinity_of_ash', 'magnesium', 'flavanoids', 'proanthocyanins', 'hue']
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  4.38
# 1             2.81  5.68
# 2             2.18  7.80
# 3             1.82  4.32
# 4             1.97  6.75

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.iloc[:3,0] = np.nan
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.78               11.2        100        2.76
# 1        NaN        2.36               18.6        101        3.24
# 2        NaN        1.95               16.8        113        3.49
# 3      13.24        2.59               21.0        118        2.69
# 4      14.20        1.76               15.2        112        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5         95        0.61
# 173    13.40        3.91               23.0        102        0.75
# 174    13.27        4.28               20.0        120        0.69
# 175    13.17        2.59               20.0        120        0.68
# 176    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins    hue
# 0               1.28   4.38
# 1               2.81   5.68
# 2               2.18   7.80
# 3               1.82   4.32
# ...

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.iloc[2:4,3] = np.nan
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.78               11.2      100.0        2.76
# 1        NaN        2.36               18.6      101.0        3.24
# 2        NaN        1.95               16.8        NaN        3.49
# 3      13.24        2.59               21.0        NaN        2.69
# 4      14.20        1.76               15.2      112.0        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins    hue
# 0               1.28   4.38
# 1               2.81   5.68
# 2               2.18   7.80
# 3               1.82   4.32
# ...

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine.alcohol.fillna(10,inplace = True)
wine.magnesium.fillna(100,inplace = True)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.78               11.2      100.0        2.76
# 1    10.00        2.36               18.6      101.0        3.24
# 2    10.00        1.95               16.8      100.0        3.49
# 3    13.24        2.59               21.0      100.0        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  4.38
# 1             2.81  5.68
# 2             2.18  7.80
# 3             1.82  4.32
# 4             1.97  6.75

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
random = np.random.randint(10, size = 10)
random
# Out:
# array([9, 8, 0, 0, 9, 9, 4, 8, 3, 9])

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
#index number 0,3,4,8,9 in column magnesium should be Nan
wine.magnesium[random] = np.nan
wine.head(10)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.78               11.2        NaN        2.76
# 1    10.00        2.36               18.6      101.0        3.24
# 2    10.00        1.95               16.8      100.0        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2        NaN        3.39
# 5    14.39        1.87               14.6       96.0        2.52
# 6    14.06        2.15               17.6      121.0        2.51
# 7    14.83        1.64               14.0       97.0        2.98
# 8    13.86        1.35               16.0        NaN        3.15
# 9    14.10        2.16               18.0        NaN        3.32
#
#    proanthocyanins   hue
# 0             1.28  4.38
# 1             2.81  5.68
# 2             2.18  7.80
# 3             1.82  4.32
# 4             1.97  6.75
# 5             1.98  5.25
# 6             1.25  5.05
# 7             1.98  5.20
# ...

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine.isna().sum()
#that's right, 5 cell in column magnesium is NaN
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            5
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine = wine.dropna()
wine.head(10)
# Out:
#     alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 1     10.00        2.36               18.6      101.0        3.24
# 2     10.00        1.95               16.8      100.0        3.49
# 5     14.39        1.87               14.6       96.0        2.52
# 6     14.06        2.15               17.6      121.0        2.51
# 7     14.83        1.64               14.0       97.0        2.98
# 10    14.12        1.48               16.8       95.0        2.43
# 11    13.75        1.73               16.0       89.0        2.76
# 12    14.75        1.73               11.4       91.0        3.69
# 13    14.38        1.87               12.0      102.0        3.64
# 14    13.63        1.81               17.2      112.0        2.91
#
#     proanthocyanins   hue
# 1              2.81  5.68
# 2              2.18  7.80
# 5              1.98  5.25
# 6              1.25  5.05
# 7              1.98  5.20
# 10             1.57  5.00
# 11             1.81  5.60
# ...

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
#with parathness, return a bool
wine.alcohol.notnull()
# Out:
# 1      True
# 2      True
# 5      True
# 6      True
# 7      True
#        ...
# 172    True
# 173    True
# 174    True
# 175    True
# 176    True
# Name: alcohol, Length: 172, dtype: bool

# %%
#without parathness, return the non-null value itself
wine.alcohol.notnull
# Out:
# <bound method Series.notnull of 0      10.00
# 1      10.00
# 2      14.39
# 3      14.06
# 4      14.83
#        ...
# 167    13.71
# 168    13.40
# 169    13.27
# 170    13.17
# 171    14.13
# Name: alcohol, Length: 172, dtype: float64>

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine = wine.reset_index(drop=True)
wine.head(10)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        2.36               18.6      101.0        3.24
# 1    10.00        1.95               16.8      100.0        3.49
# 2    14.39        1.87               14.6       96.0        2.52
# 3    14.06        2.15               17.6      121.0        2.51
# 4    14.83        1.64               14.0       97.0        2.98
# 5    14.12        1.48               16.8       95.0        2.43
# 6    13.75        1.73               16.0       89.0        2.76
# 7    14.75        1.73               11.4       91.0        3.69
# 8    14.38        1.87               12.0      102.0        3.64
# 9    13.63        1.81               17.2      112.0        2.91
#
#    proanthocyanins   hue
# 0             2.81  5.68
# 1             2.18  7.80
# 2             1.98  5.25
# 3             1.25  5.05
# 4             1.98  5.20
# 5             1.57  5.00
# 6             1.81  5.60
# 7             2.81  5.40
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
#get the row with max value of alcohol

wine.iloc[[wine['alcohol'].idxmax()]]
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 4    14.83        1.64               14.0       97.0        2.98
#
#    proanthocyanins  hue
# 4             1.98  5.2
